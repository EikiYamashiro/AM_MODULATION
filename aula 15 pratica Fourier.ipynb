# %% [markdown]
# Camada Física da Computação 2020/2
#
# Aula 14  - **Prática em Fourier**
#
# Rodrigo Carareto rodrigoc5@insper.edu.br

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.fftpack import fft, fftshift

# %%
def generateSin(freq, time, fs):
    n = time*fs #numero de pontos
    x = np.linspace(0.0, time, n)  # eixo do tempo
    s = np.sin(freq*x*2*np.pi)
    return (x, s)

# %%
def calcFFT(signal, fs):
    # https://docs.scipy.org/doc/scipy/reference/tutorial/fftpack.html
    #y  = np.append(signal, np.zeros(len(signal)*fs))
    N  = len(signal)
    T  = 1/fs
    xf = np.linspace(-1.0/(2.0*T), 1.0/(2.0*T), N)
    yf = fft(signal)
    return(xf, fftshift(yf))

# %% [markdown]
# ## Propriedades dos sinais

# %%
fs  = 200   # pontos por segundo (frequência de amostragem)
A   = 1.5   # Amplitude
F   = 1     # Hz
T   = 4     # Tempo em que o seno será gerado
t   = np.linspace(-T/2,T/2,T*fs)

# %% [markdown]
# # Prática em Fourier

# %% [markdown]
# ## Senoide única
#
#  - Gere uma senoide de 5Hz
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo e fase)
#  - Analíse a composição espectal desse sinal.
#  - Calcule a banda do sinal

# %%
x, y = generateSin(5,T,fs)
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))

plt.figure()
plt.stem(X,np.imag(Y))
# Out:
# <ipython-input-5-4a3856ad55a6>:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-5-4a3856ad55a6>:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Senoides
#
#  - Gere duas senoide de mesma amplitude e frequência 5Hz e 8Hz
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo)
#  - Analíse a composição espectal desse sinal.

# %%
x1, y1 = generateSin(5,T,fs)
x2, y2 = generateSin(6,T,fs)
x3, y3 = generateSin(7,T,fs)
x4, y4 = generateSin(8,T,fs)
y=y1 + 2*y2 + 3*y3 + y4
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))
plt.xlim(-15, 15)

plt.figure()
plt.stem(X,np.imag(Y))
plt.xlim(-15, 15)
# Out:
# <ipython-input-6-756daf93706a>:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-6-756daf93706a>:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# (-15.0, 15.0)

# %% [markdown]
# ## Onda Quadrada nivel DC = 0
#
#  - Gere uma onda quadrada em torno do eixo X de amplitude 3 e frequência 1Hz
#      - dica : signal.square
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo e fase)
#  - Analíse a composição espectal desse sinal.

# %%
y = signal.square(2 * np.pi * 20 * t, 0.5)
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))

plt.figure()
plt.stem(X,np.imag(Y))
# Out:
# <ipython-input-7-30fed4e17a99>:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-7-30fed4e17a99>:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Pulso
#
#  - Gere um pulso em torno da origem de duração (1.5s, 1s, 0.5s, 0.025s)
#      - dica : signal.square
#
# ### Para analisar
#
#  - Exiba o sinal no tempo e o Fourier dos sinais (módulo )
#  - Analíse a composição espectal dos pulsos (com duração distintas)
#  - Calcule as bandas dos sinais

# %%
y1 = signal.square(2 * np.pi * 1/3 * (t+.75), 0.5)
y2 = signal.square(2 * np.pi * .5 * (t+.5), 0.5)
y3 = signal.square(2 * np.pi * 1 * (t+.25), 0.5)
y4 = signal.square(2 * np.pi * 20 * (t+.05/4), 0.5)

for x in range(len(t)):
    if(t[x]>.5 or t[x]<-.5):
        y2[x]=0
    if(t[x]>.25 or t[x]<-.25):
        y3[x]=0
    if(t[x]>.0125 or t[x]<-.0125):
        y4[x]=0


y=y3
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))
plt.xlim(-20,20)

plt.figure()
plt.stem(X,np.imag(Y))
plt.xlim(-20,20)
# Out:
# <ipython-input-8-39366022f45a>:21: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-8-39366022f45a>:25: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# (-20.0, 20.0)

# %% [markdown]
# ## FFT PYTHON
# Vamos testar o algoritmo FFT do python e a função de localizar picos. Para isso, inicialmente, grave um arquivo de audio de poucos segundos. Em seguida, importe e execute esse audio. Altere a taxa de amostragem e veja o que ocorre. Tente entender.

# %%
from suaBibSignal import *
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
import soundfile   as sf


#leituara do arquivo audio
fs = 44100   # taxqa de amostagem (sample rate)
sd.default.samplerate = fs
sd.default.channels = 1
audio, samplerate = sf.read('camFis.wav')
yAudio = audio[:,1]
samplesAudio = len(yAudio)
sd.play(audio)
sd.wait()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-04f20fc37293> in <module>
#      10 sd.default.samplerate = fs
#      11 sd.default.channels = 1
# ---> 12 audio, samplerate = sf.read('camFis.wav')
#      13 yAudio = audio[:,1]
#      14 samplesAudio = len(yAudio)
#
# C:\ProgramData\Anaconda3\lib\site-packages\soundfile.py in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     254
#     255     """
# --> 256     with SoundFile(file, 'r', samplerate, channels,
#     257                    subtype, endian, format, closefd) as f:
#     258         frames = f._prepare_read(start, stop, frames)
#
# C:\ProgramData\Anaconda3\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     625         self._info = _create_info_struct(file, mode, samplerate, channels,
#     626                                          format, subtype, endian)
# --> 627         self._file = self._open(file, mode_int, closefd)
#     628         if set(mode).issuperset('r+') and self.seekable():
#     629             # Move write position to 0 (like in Python file objects)
#
# C:\ProgramData\Anaconda3\lib\site-packages\soundfile.py in _open(self, file, mode_int, closefd)
#    1168             if isinstance(file, _unicode):
#    1169                 if _sys.platform == 'win32':
# -> 1170                     openfunction = _snd.sf_wchar_open
#    1171                 else:
#    1172                     file = file.encode(_sys.getfilesystemencoding())
#
# AttributeError: cffi library 'C:\ProgramData\Anaconda3\Library\bin\sndfile.dll' has no function, constant or global variable named 'sf_wchar_open'

# %% [markdown]
# Plot o gráfico do sinal no tempo.

# %%
plt.plot(yAudio)
plt.grid()
plt.title('Oi no tempo')

# %% [markdown]
# Obtenha transformada de Fourier do arquivo, mostre o gráfico dos módulos.

# %%
X, Y = calcFFT(yAudio, samplerate)
plt.figure("Fourier Audio")
plt.plot(X, np.abs(Y))
plt.grid()
plt.title('Oi Frequencia')

# %% [markdown]
# Obtenha as 5 frequências mais presentes na composição do sinal.

# %%
import peakutils
index = peakutils.indexes(np.abs(Y), thres=0.8, min_dist=50)
print("index de picos {}" .format(index))
for freq in X[index]:
    print("freq de pico sao {}" .format(freq))
